# %%
#teste de sincronização

# %%
import pandas as pd
import numpy as np

# %%
# !git status
# !git add .
# !git commit -m "arroche em python"
# !git push
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean
# Everything up-to-date
